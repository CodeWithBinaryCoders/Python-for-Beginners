# %%
x = 5
y = 6.7
name = "Alik"

# %%
print(x, y, name)
# Out:
# 5 6.7 Alik

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
type(y)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
my_var = True
var = False

# %%
my_var
# Out:
# True

# %%
type(my_var)
# Out:
# bool
